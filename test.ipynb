# %% [markdown]
# <a href="https://colab.research.google.com/github/piquelab/fastdemux/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %automagic 1
# Out:
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Restart runtime if necessary
# !conda install -c bioconda htslib
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...
# Channels:
#  - bioconda
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - htslib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     c-ares-1.34.6              |       hb03c661_0         203 KB  conda-forge
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
#     conda-24.11.3              |  py311h38be061_0         1.1 MB  conda-forge
#     htslib-1.23                |       h566b1c6_0         1.1 MB  bioconda
# ...

# %%
# !bgzip --version
# Out:
# bgzip (htslib) 1.23
# Copyright (C) 2025 Genome Research Ltd.

# %%
# !cmake --version
# Out:
# cmake version 3.31.10
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !cmake --help
# Out:
# Usage
#
#   cmake [options] <path-to-source>
#   cmake [options] <path-to-existing-build>
#   cmake [options] -S <path-to-source> -B <path-to-build>
#
# Specify a source directory to (re-)generate a build system for it in the
# current working directory.  Specify an existing build directory to
# re-generate its build system.
#
# Options
#   -S <path-to-source>          = Explicitly specify a source directory.
#   -B <path-to-build>           = Explicitly specify a build directory.
#   -C <initial-cache>           = Pre-load a script to populate the cache.
#   -D <var>[:<type>]=<value>    = Create or update a cmake cache entry.
#   -U <globbing_expr>           = Remove matching entries from CMake cache.
#   -G <generator-name>          = Specify a build system generator.
#   -T <toolset-name>            = Specify toolset name if supported by
#                                  generator.
#   -A <platform-name>           = Specify platform name if supported by
# ...

# %%
# !git clone https://github.com/piquelab/fastdemux.git
# Out:
# Cloning into 'fastdemux'...
# remote: Enumerating objects: 274, done.
# remote: Counting objects: 100% (274/274), done.
# remote: Compressing objects: 100% (215/215), done.
# remote: Total 274 (delta 113), reused 199 (delta 55), pack-reused 0 (from 0)
# Receiving objects: 100% (274/274), 2.28 MiB | 8.29 MiB/s, done.
# Resolving deltas: 100% (113/113), done.

# %%
# %cd /content/fastdemux/
# !git clone https://github.com/attractivechaos/klib.git
# Out:
# /content/fastdemux
# Cloning into 'klib'...
# remote: Enumerating objects: 1421, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 1421 (delta 32), reused 28 (delta 24), pack-reused 1360 (from 2)
# Receiving objects: 100% (1421/1421), 1.25 MiB | 5.33 MiB/s, done.
# Resolving deltas: 100% (811/811), done.

# %%
# !mkdir build

# %%
# %cd build
# Out:
# /content/fastdemux/build

# %%
# !cmake ../
# Out:
# -- Configuring done (0.0s)
# -- Generating done (0.0s)
# -- Build files have been written to: /content/fastdemux/build

# %%
# !make
# Out:
# [ 16%] Building C object CMakeFiles/fastdemux.dir/fastdemux.c.o
# /content/fastdemux/fastdemux.c: In function ‘main’:
# /content/fastdemux/fastdemux.c:465:50: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘hts_pos_t’ {aka ‘long int’} [-Wformat=]
#   465 |           fprintf(stderr, "Processing %d: %d %s %d %c %c %f\n", snpcnt,rec[jj]->rid, bcf_hdr_id2name(vcf_hdr, rec[jj]->rid), rec[jj]->pos, ref_allele, alt_allele,alf);
#       |                                                 ~^                                                                           ~~~~~~~~~~~~
#       |                                                  |                                                                                  |
#       |                                                  int                                                                                hts_pos_t {aka long int}
#       |                                                 %ld
# ...

# %%
# !make install
# Out:
# [ 50%] Built target fastdemux
# [100%] Built target fastaseq
# Install the project...
# -- Install configuration: "Release"
# -- Installing: /wsu/home/groups/piquelab/apps/el7/misc/bin/fastdemux
# -- Set non-toolchain portion of runtime path of "/wsu/home/groups/piquelab/apps/el7/misc/bin/fastdemux" to ""
# -- Installing: /wsu/home/groups/piquelab/apps/el7/misc/bin/fastaseq
# -- Set non-toolchain portion of runtime path of "/wsu/home/groups/piquelab/apps/el7/misc/bin/fastaseq" to ""

# %%
# !/content/fastdemux/build/fastdemux
# Out:
# fastdemux version 0.1.1
# Usage: /content/fastdemux/build/fastdemux [options] <BAM file> <VCF file> <Barcode file> <Output prefix>
# Options:
#  -q, --min-qual-score NUM  Minimum quality score (default: 20)
#  -b, --min-base-qual NUM   Minimum base quality (default: 13)
#  --max-var REAL  Threshold on max 2*q*(1-q) to select more informative SNPs  (default: 0.100000)
#  --max-snps NUM  Max number of SNPs  (useful for debug, default: 0 All)
#  -t, --num-threads NUM  Number of OpenMP threads (default: 12)
